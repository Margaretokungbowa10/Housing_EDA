# %% [markdown]
# # Housing EDA_

# %%
import pandas as pd

# %%
import os

path = r"C:\Users\marga\Downloads\housing-housing.xlsx"
print(os.path.exists(path))
# Out:
# False

# %%
#defining the fll name of ABV columns title 
full_column_names = [
    "Per capita crime rate by town",          # CRIM
    "Proportion of residential land zoned for lots over 25,000 sq.ft.",  # ZN
    "Proportion of non-retail business acres per town",  # INDUS
    "Charles River bounds (1 if tract bounds river, 0 otherwise)",  # CHAS
    "Nitric oxides concentration (parts per 10 million)",  # NOX
    "Average number of rooms per dwelling",  # RM
    "Proportion of owner-occupied units built prior to 1940",  # AGE
    "Weighted distances to five Boston employment centers",  # DIS
    "Index of accessibility to radial highways",  # RAD
    "Full-value property tax rate per $10,000",  # TAX
    "Pupil-teacher ratio by town",  # PTRATIO
    "1000(Bk - 0.63)^2 where Bk is proportion of blacks by town",  # B
    "Percentage lower status of the population",  # LSTAT
    "Median value of owner-occupied homes in $1000s"  # MEDV
]

# Print them all
for name in full_column_names:
    print(name)
# Out:
# Per capita crime rate by town
# Proportion of residential land zoned for lots over 25,000 sq.ft.
# Proportion of non-retail business acres per town
# Charles River bounds (1 if tract bounds river, 0 otherwise)
# Nitric oxides concentration (parts per 10 million)
# Average number of rooms per dwelling
# Proportion of owner-occupied units built prior to 1940
# Weighted distances to five Boston employment centers
# Index of accessibility to radial highways
# Full-value property tax rate per $10,000
# Pupil-teacher ratio by town
# 1000(Bk - 0.63)^2 where Bk is proportion of blacks by town
# Percentage lower status of the population
# Median value of owner-occupied homes in $1000s

# %%
import pandas as pd

housing = pd.read_csv(r"C:\Users\marga\Downloads\housing.csv")

housing
# Out:
#          CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# 0    0.000000  0.165514  0.067815   0.0  0.273696  0.455845  0.495675
# 1    0.000236  0.000000  0.242302   0.0  0.159428  0.436962  0.578128
# 2    0.000236  0.000000  0.242302   0.0  0.159428  0.527320  0.469617
# 3    0.000293  0.000000  0.063050   0.0  0.139941  0.505947  0.365901
# 4    0.000705  0.000000  0.063050   0.0  0.139941  0.523014  0.424170
# ..        ...       ...       ...   ...       ...       ...       ...
# 501  0.000633  0.000000  0.420455   0.0  0.327021  0.458029  0.519848
# 502  0.000438  0.000000  0.420455   0.0  0.327021  0.398993  0.565337
# 503  0.000612  0.000000  0.420455   0.0  0.327021  0.503402  0.645695
# 504  0.001160  0.000000  0.420455   0.0  0.327021  0.482097  0.636473
# 505  0.000462  0.000000  0.420455   0.0  0.327021  0.387355  0.589045
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# ...

# %%
## Understanding my Data types

# %%
housing.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
### checking for missing_values And also getting the count

# %%
housing.isna().value_counts()
# Out:
# CRIM   ZN     INDUS  CHAS   NOX    RM     AGE    DIS    RAD    TAX    PTRATIO  B      LSTAT  MEDV
# False  False  False  False  False  False  False  False  False  False  False    False  False  False    506
# Name: count, dtype: int64

# %%
# Conducting stat on data

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.036362    0.090296    0.391378    0.047945    0.284651    0.416052
# std      0.077805    0.175973    0.251479    0.176055    0.170604    0.088357
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000851    0.000000    0.173387    0.000000    0.123710    0.368380
# 50%      0.002808    0.000000    0.338343    0.000000    0.273696    0.410307
# 75%      0.040430    0.117783    0.646628    0.000000    0.399963    0.461718
# max      0.693147    0.693147    1.000000    0.693147    0.693147    0.693147
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.500107    0.206017    0.282694    0.328215    0.473075    0.631214
# ...

# %% [markdown]
# # Basic Visual Exploration

# %%
#Histogram of all numeric columns
import pandas as pd

housing = pd.read_csv(r"C:\Users\marga\Downloads\housing.csv")

import matplotlib.pyplot as plt

housing.hist(figsize=(15,10))
plt.show()

# %%
# Correlation Heatmap

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(housing.corr(), annot= True, cmap= 'coolwarm')
plt.show()

# %%
# Scatter plot for key features vs target(Median Home Value)

# %%
#renamed coluns for readable full names  

housing.columns = [
    "Per capita crime rate by town",          
    "Proportion of residential land zoned for lots over 25,000 sq.ft.",  
    "Proportion of non-retail business acres per town",  
    "Charles River bounds (1 if tract bounds river, 0 otherwise)",  
    "Nitric oxides concentration (parts per 10 million)",  
    "Average number of rooms per dwelling",  
    "Proportion of owner-occupied units built prior to 1940",  
    "Weighted distances to five Boston employment centers",  
    "Index of accessibility to radial highways",  
    "Full-value property tax rate per $10,000",  
    "Pupil-teacher ratio by town",  
    "1000(Bk - 0.63)^2 where Bk is proportion of blacks by town",  
    "Percentage lower status of the population",  
    "Median value of owner-occupied homes in $1000s"
]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    x=housing['Average number of rooms per dwelling'],
    y=housing['Median value of owner-occupied homes in $1000s'],
    data=housing
)
plt.title("Rooms vs median home value")
plt.show()

# %%
#Quick check to confrim columns names 
print(housing.columns.tolist())
# Out:
# ['Per capita crime rate by town', 'Proportion of residential land zoned for lots over 25,000 sq.ft.', 'Proportion of non-retail business acres per town', 'Charles River bounds (1 if tract bounds river, 0 otherwise)', 'Nitric oxides concentration (parts per 10 million)', 'Average number of rooms per dwelling', 'Proportion of owner-occupied units built prior to 1940', 'Weighted distances to five Boston employment centers', 'Index of accessibility to radial highways', 'Full-value property tax rate per $10,000', 'Pupil-teacher ratio by town', '1000(Bk - 0.63)^2 where Bk is proportion of blacks by town', 'Percentage lower status of the population', 'Median value of owner-occupied homes in $1000s']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Charles River bounds (1 if tract bounds river, 0 otherwise)',
    y='Median value of owner-occupied homes in $1000s',
    data=housing

)
plt.title("Median Home Value by charles River Boundary")
plt.show()
